# %% [markdown]
# # Demo Table
#
# Below is a simple table rendered from Markdown:
#
# | Name   | Team   | Score |
# | :----- | :----: | ----: |
# | Alice  | Red    | 42    |
# | Bob    | Blue   | 37    |
# | Carol  | Green  | 45    |
